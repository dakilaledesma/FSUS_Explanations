# %% [markdown]
# <a href="https://colab.research.google.com/github/dakilaledesma/FSUS_Explanations/blob/main/notebooks/test/S2D_O224G4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%time
! unzip -q drive/MyDrive/UNC/S2022P/GBIF_O_21_fourth.zip -d /content/temp
! mv /content/temp/content/dataset/test /content/test
! rm -rf /content/temp
# Out:
# CPU times: user 47.5 ms, sys: 24.1 ms, total: 71.5 ms
# Wall time: 5.61 s

# %%
! git clone https://github.com/rwightman/pytorch-image-models.git
# Out:
# Cloning into 'pytorch-image-models'...
# remote: Enumerating objects: 10798, done.
# remote: Counting objects: 100% (325/325), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 10798 (delta 184), reused 239 (delta 154), pack-reused 10473
# Receiving objects: 100% (10798/10798), 20.43 MiB | 23.35 MiB/s, done.
# Resolving deltas: 100% (7896/7896), done.

# %%
! python -u ./pytorch-image-models/inference.py test -b 128 --input-size 3 224 224 --num-classes 300 --no-test-pool --checkpoint /content/drive/MyDrive/UNC/S2022P/output/20220809-160023-sequencer2d_l-224/last.pth.tar --model sequencer2d_l
# Out:
# Loaded state_dict from checkpoint '/content/drive/MyDrive/UNC/S2022P/output/20220809-160023-sequencer2d_l-224/last.pth.tar'
# Model sequencer2d_l created, param count: 54028716
# Predict: [0/7] Time 10.735 (10.735)

# %%
from glob import glob
import os

class_dict = {}
for fn in glob("test/**/*.*", recursive=True):
  cat = int(fn.split("/")[-2])
  bn = os.path.basename(fn)

  class_dict[bn] = cat

# %%
def get_acc():
  output_file = open("topk_ids.csv")
  output_lines = output_file.readlines()

  corr = 0
  total = 0
  for line in output_lines:
    
    line = line.strip().split(",")
    cat = class_dict[line[0]]
    pred = int(line[1])

    if cat == pred:
      corr += 1

    total += 1

    print(cat, pred)

  print(corr / total)

# %%
# S2D 224
get_acc()
# Out:
# 0 0
# 0 0
# 0 0
# 0 0
# 0 49
# 1 1
# 1 11
# 1 1
# 1 1
# 1 1
# 2 2
# 2 54
# 2 2
# 2 37
# 2 2
# 3 3
# 3 18
# 4 170
# 4 18
# 4 4
# 4 4
# 5 7
# 5 7
# 5 1
# 5 85
# 6 6
# 6 66
# 7 7
# 7 17
# 7 150
# 7 16
# 7 162
# 8 8
# 8 17
# 8 8
# 8 8
# 8 8
# 9 9
# 9 53
# 9 9
# 9 9
# 9 85
# 10 10
# 10 133
# 10 133
# 10 10
# 10 133
# 11 11
# 11 11
# 11 12
# 11 11
# 11 151
# 12 12
# 12 12
# 12 14
# 12 14
# 12 11
# 13 13
# 13 15
# 13 15
# 13 13
# 14 12
# 14 51
# 14 12
# 14 14
# 14 149
# 15 15
# 15 15
# 15 15
# 15 15
# 15 11
# 16 16
# 16 17
# 16 16
# 16 16
# 16 168
# 17 16
# 17 17
# 17 17
# 17 17
# 17 17
# 18 47
# 18 18
# 18 18
# 18 47
# 19 19
# 19 20
# 19 19
# 19 19
# 19 19
# 20 20
# 20 17
# 20 20
# 20 19
# 20 20
# 21 21
# 21 19
# 21 21
# 21 63
# 22 22
# 22 25
# 22 22
# 22 28
# 22 22
# 23 23
# 23 23
# 23 23
# 23 23
# 23 23
# 24 24
# 24 24
# 24 24
# 24 80
# 24 24
# 25 22
# 25 23
# 25 25
# 25 23
# 25 80
# 26 152
# 26 26
# 26 26
# 26 26
# 26 26
# 27 27
# 27 85
# 27 27
# 27 27
# 27 176
# 28 26
# 28 28
# 28 22
# ...
